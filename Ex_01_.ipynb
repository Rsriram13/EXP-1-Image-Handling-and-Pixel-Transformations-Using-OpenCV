# %% [markdown]
# ### Ex. No: 01
# ## Image Handling and Pixel Transformations Using OpenCV
#
# **Name:** Sriram R    **Reg. No:** 212223230215
#
# **Slot:** T1-H15

# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Read the image ('Eagle_in_Flight.jpg') using OpenCV imread() as a grayscale image.

# %%
img = cv2.imread('/content/Eagle_in_Flight.jpg', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# 2. Print the image width, height & Channel

# %%
height, width = img.shape
print("Width:", width)
print("Height:", height)
print("Channel: 1")
# Out:
# Width: 768
# Height: 600
# Channel: 1

# %% [markdown]
# 3. Display the image using matplotlib imshow().

# %%
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# 4. Save the image as a PNG file using OpenCV imwrite().

# %%
cv2.imwrite('Eagle_gray.png', img)
# Out:
# True

# %% [markdown]
# 5. Read the saved image above as a color image using cv2.cvtColor().

# %%
img_color = cv2.imread('Eagle_gray.png')
img_color = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 6. Display the Colour image using matplotlib imshow() & Print the image width, height & channel

# %%
plt.imshow(img_color)
plt.axis('off')
plt.show()

# %%
height, width, channel = img_color.shape
print("Width:", width)
print("Height:", height)
print("Channel:", channel)
# Out:
# Width: 768
# Height: 600
# Channel: 3

# %% [markdown]
# 7. Crop the image to extract any specific (Eagle alone)  object from the image.

# %%
cropped = img_color[95:425, 150:550]

plt.imshow(cropped)
plt.axis('off')
plt.show()

# %% [markdown]
# 8. Resize the image up by a factor of 2x.

# %%
resized = cv2.resize(cropped, None, fx=2, fy=2)
plt.imshow(resized)
plt.axis('off')
plt.show()

# %% [markdown]
# 9. Flip the cropped/resized image horizontally. (Eagle Image)

# %%
flipped = cv2.flip(resized, 1)
plt.imshow(flipped)
plt.axis('off')
plt.show()

# %% [markdown]
# 10. Read in the image ('Apollo-11-launch.jpg').

# %%
apollo = cv2.imread('/content/Apollo-11-launch.jpg')

# %% [markdown]
# 11. Add the following text to the dark area at the bottom of the image (centered on the image):

# %%
text = 'Apollo 11 Saturn V Launch, July 16, 1969'
font_face = cv2.FONT_HERSHEY_PLAIN
# YOUR CODE HERE: use putText()
h, w, _ = apollo.shape
text_size = cv2.getTextSize(text, font_face, 2, 2)[0]
text_x = (w - text_size[0]) // 2
text_y = h - 20

# %%
apollo_text = cv2.putText(apollo.copy(), text, (text_x, text_y),font_face, 2, (255,255,255), 2)

# %%
plt.imshow(apollo_text)
plt.axis('off')
plt.show()

# %% [markdown]
# 12. Draw a magenta rectangle that encompasses the launch tower and the rocket.

# %%
# rect_color = magenta
# YOUR CODE HERE
rect_color = (255, 0, 255)

apollo_rect = cv2.rectangle(apollo_text.copy(),(450, 100), (750, 650),rect_color, 3)

# %% [markdown]
# 13. Display the final annotated image.

# %%
plt.imshow(apollo_rect)
plt.axis('off')
plt.show()

# %% [markdown]
# 14. Read the image ('boy.jpg').

# %%
img = cv2.imread('/content/boy.jpg')

# %% [markdown]
# 15. Adjust the brightness of the image.

# %%
# Create a matrix of ones (with data type float64)
# matrix_ones =
# YOUR CODE HERE
matrix_ones = np.ones(img.shape, dtype="uint8") * 50

# %% [markdown]
# 16. Create brighter and darker images.

# %%
#img_brighter = cv2.add(img, matrix)
#img_darker = cv2.subtract(img, matrix)
# YOUR CODE HERE
img_brighter = cv2.add(img, matrix_ones)
img_darker = cv2.subtract(img, matrix_ones)

# %% [markdown]
# 17. Display the images (Original Image, Darker Image, Brighter Image).

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,3,1);plt.imshow(img);plt.title("Original")
plt.subplot(1,3,2);plt.imshow(img_darker);plt.title("Darker")
plt.subplot(1,3,3);plt.imshow(img_brighter);plt.title("Brighter")
plt.show()

# %% [markdown]
# 18. Modify the image contrast.

# %%
# Create two higher contrast images using the 'scale' option with factors of 1.1 and 1.2 (without overflow fix)
# matrix1 =
# matrix2 =
# img_higher1 =
# img_higher2 =
# YOUR CODE HERE
img_higher1 = cv2.convertScaleAbs(img, alpha=1.1, beta=0)
img_higher2 = cv2.convertScaleAbs(img, alpha=1.2, beta=0)
img_lower_contrast = cv2.convertScaleAbs(img, alpha=0.8, beta=0)

# %% [markdown]
# 19. Display the images (Original, Lower Contrast, Higher Contrast).

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,3,1);plt.imshow(img);plt.title("Original")
plt.subplot(1,3,2);plt.imshow(img_higher1);plt.title("Contrast 1.1")
plt.subplot(1,3,3);plt.imshow(img_higher2);plt.title("Contrast 1.2")
plt.show()

# %% [markdown]
# 20. Split the image (boy.jpg) into the B,G,R components & Display the channels.

# %%
img_bgr = cv2.imread('/content/boy.jpg')
B, G, R = cv2.split(img_bgr)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,3,1);plt.imshow(B, cmap='gray');plt.title("Blue Channel")
plt.subplot(1,3,2);plt.imshow(G, cmap='gray');plt.title("Green Channel")
plt.subplot(1,3,3);plt.imshow(R, cmap='gray');plt.title("Red Channel")
plt.show()

# %% [markdown]
# 21. _merged the R, G, B , display along with orginal image

# %%
merged_rgb = cv2.merge((R, G, B))

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1);plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB));plt.title("Original");plt.axis('off')
plt.subplot(1,2,2);plt.imshow(merged_rgb);plt.title("Merged RGB");plt.axis('off')
plt.show()

# %% [markdown]
# 22. Split the image into the H, S, V components &  Display the channels.

# %%
hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)
H, S, V = cv2.split(hsv)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,3,1);plt.imshow(H, cmap='gray');plt.title("Hue");plt.axis('off')
plt.subplot(1,3,2);plt.imshow(S, cmap='gray');plt.title("Saturation");plt.axis('off')
plt.subplot(1,3,3);plt.imshow(V, cmap='gray');plt.title("Value");plt.axis('off')
plt.show()

# %% [markdown]
# 23. _merged the H, S, V, display along with orginal image

# %%
merged_hsv = cv2.merge((H, S, V))
merged_bgr = cv2.cvtColor(merged_hsv, cv2.COLOR_HSV2BGR)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1);plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB));plt.title("Original");plt.axis('off')
plt.subplot(1,2,2);plt.imshow(cv2.cvtColor(merged_bgr, cv2.COLOR_BGR2RGB));plt.title("Merged HSV");plt.axis('off')
plt.show()
